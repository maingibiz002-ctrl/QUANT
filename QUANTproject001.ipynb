# %% [markdown]
# <a href="https://colab.research.google.com/github/maingibiz002-ctrl/QUANT/blob/main/QUANTproject001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# IMPORTING  PACKAGES TO BE USED THROUGHOUT THE PROGRAMME

# %%
import yfinance as yf
import pandas as pd
import datetime as dt
import numpy as np

# %% [markdown]
# TIME HORIZONS

# %%
enddate = dt.datetime.now()
startdate = enddate - dt.timedelta(days = 365 * 5)
print(startdate)
print(enddate)
# Out:
# 2021-09-21 04:52:54.010325
# 2026-09-20 04:52:54.010325

# %% [markdown]
# STOCK CHOICES
